# %%
import pandas as pd

# %%
df = pd.read_csv('survey_results_public.csv', encoding='unicode_escape')

# %%
df.head()
# Out:
#    ResponseId                                         MainBranch  \
# 0           1                                      None of these
# 1           2                     I am a developer by profession
# 2           3  I am not primarily a developer, but I write co...
# 3           4                     I am a developer by profession
# 4           5                     I am a developer by profession
#
#             Employment                            RemoteWork  \
# 0                  NaN                                   NaN
# 1  Employed, full-time                          Fully remote
# 2  Employed, full-time  Hybrid (some remote, some in-person)
# 3  Employed, full-time                          Fully remote
# 4  Employed, full-time  Hybrid (some remote, some in-person)
#
#                            CodingActivities  \
# 0                                       NaN
# 1  Hobby;Contribute to open-source projects
# 2                                     Hobby
# ...

# %%
df.shape
# Out:
# (73268, 79)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73268 entries, 0 to 73267
# Data columns (total 79 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   ResponseId                      73268 non-null  int64
#  1   MainBranch                      73268 non-null  object
#  2   Employment                      71709 non-null  object
#  3   RemoteWork                      58958 non-null  object
#  4   CodingActivities                58899 non-null  object
#  5   EdLevel                         71571 non-null  object
#  6   LearnCode                       71580 non-null  object
#  7   LearnCodeOnline                 50685 non-null  object
#  8   LearnCodeCoursesCert            29389 non-null  object
#  9   YearsCode                       71331 non-null  object
#  10  YearsCodePro                    51833 non-null  object
#  11  DevType                         61302 non-null  object
# ...

# %%
df.columns
# Out:
# Index(['ResponseId', 'MainBranch', 'Employment', 'RemoteWork',
#        'CodingActivities', 'EdLevel', 'LearnCode', 'LearnCodeOnline',
#        'LearnCodeCoursesCert', 'YearsCode', 'YearsCodePro', 'DevType',
#        'OrgSize', 'PurchaseInfluence', 'BuyNewTool', 'Country', 'Currency',
#        'CompTotal', 'CompFreq', 'LanguageHaveWorkedWith',
#        'LanguageWantToWorkWith', 'DatabaseHaveWorkedWith',
#        'DatabaseWantToWorkWith', 'PlatformHaveWorkedWith',
#        'PlatformWantToWorkWith', 'WebframeHaveWorkedWith',
#        'WebframeWantToWorkWith', 'MiscTechHaveWorkedWith',
#        'MiscTechWantToWorkWith', 'ToolsTechHaveWorkedWith',
#        'ToolsTechWantToWorkWith', 'NEWCollabToolsHaveWorkedWith',
#        'NEWCollabToolsWantToWorkWith', 'OpSysProfessional use',
#        'OpSysPersonal use', 'VersionControlSystem', 'VCInteraction',
#        'VCHostingPersonal use', 'VCHostingProfessional use',
#        'OfficeStackAsyncHaveWorkedWith', 'OfficeStackAsyncWantToWorkWith',
# ...

# %%
df['LearnCode'].value_counts()
# Out:
# School (i.e., University, College, etc)                                                                                                                                                                                      3669
# Other online resources (e.g., videos, blogs, forum)                                                                                                                                                                          3292
# Books / Physical media;Other online resources (e.g., videos, blogs, forum);School (i.e., University, College, etc)                                                                                                           2873
# Other online resources (e.g., videos, blogs, forum);School (i.e., University, College, etc)                                                                                                                                  2697
# ...

# %%
df.loc[0:2,'Employment'].value_counts()
# Out:
# Employed, full-time    2
# Name: Employment, dtype: int64

# %%
pd.set_option('display.max_columns',10)
pd.set_option('display.max_rows',20)

# %%
df
# Out:
#        ResponseId                                         MainBranch  \
# 0               1                                      None of these
# 1               2                     I am a developer by profession
# 2               3  I am not primarily a developer, but I write co...
# 3               4                     I am a developer by profession
# 4               5                     I am a developer by profession
# ...           ...                                                ...
# 73263       73264                     I am a developer by profession
# 73264       73265                     I am a developer by profession
# 73265       73266  I am not primarily a developer, but I write co...
# 73266       73267                     I am a developer by profession
# 73267       73268  I used to be a developer by profession, but no...
#
#                                               Employment  \
# 0                                                    NaN
# ...

# %%
df.set_index('ResponseId',inplace=True)

# %%
df.sort_index(ascending=True)
# Out:
#                                                    MainBranch  \
# ResponseId
# 1                                               None of these
# 2                              I am a developer by profession
# 3           I am not primarily a developer, but I write co...
# 4                              I am a developer by profession
# 5                              I am a developer by profession
# ...                                                       ...
# 73264                          I am a developer by profession
# 73265                          I am a developer by profession
# 73266       I am not primarily a developer, but I write co...
# 73267                          I am a developer by profession
# 73268       I used to be a developer by profession, but no...
#
#                                                    Employment  \
# ResponseId
# 1                                                         NaN
# 2                                         Employed, full-time
# ...

# %%
df['RemoteWork']
# Out:
# ResponseId
# 1                                         NaN
# 2                                Fully remote
# 3        Hybrid (some remote, some in-person)
# 4                                Fully remote
# 5        Hybrid (some remote, some in-person)
#                          ...
# 73264                            Fully remote
# 73265                          Full in-person
# 73266    Hybrid (some remote, some in-person)
# 73267    Hybrid (some remote, some in-person)
# 73268                            Fully remote
# Name: RemoteWork, Length: 73268, dtype: object

# %%
x=['Fully remote','Full in-person']
y=df['RemoteWork'].isin(x)
df[y]
# Out:
#                                                    MainBranch  \
# ResponseId
# 2                              I am a developer by profession
# 4                              I am a developer by profession
# 10                             I am a developer by profession
# 12          I am not primarily a developer, but I write co...
# 14                             I am a developer by profession
# ...                                                       ...
# 73249                          I am a developer by profession
# 73251                          I am a developer by profession
# 73264                          I am a developer by profession
# 73265                          I am a developer by profession
# 73268       I used to be a developer by profession, but no...
#
#                                                    Employment      RemoteWork  \
# ResponseId
# 2                                         Employed, full-time    Fully remote
# ...

# %%
df.apply(len)
# Out:
# MainBranch             73268
# Employment             73268
# RemoteWork             73268
# CodingActivities       73268
# EdLevel                73268
#                        ...
# TrueFalse_2            73268
# TrueFalse_3            73268
# SurveyLength           73268
# SurveyEase             73268
# ConvertedCompYearly    73268
# Length: 78, dtype: int64

# %%
df.apply(len,axis='columns')
# Out:
# ResponseId
# 1        78
# 2        78
# 3        78
# 4        78
# 5        78
#          ..
# 73264    78
# 73265    78
# 73266    78
# 73267    78
# 73268    78
# Length: 73268, dtype: int64

# %%
df.apply(pd.Series.min)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_26140\588033122.py in <module>
# ----> 1 df.apply(pd.Series.min)
#
# c:\Users\A\anaconda3\lib\site-packages\pandas\core\frame.py in apply(self, func, axis, raw, result_type, args, **kwargs)
#    8846             kwargs=kwargs,
#    8847         )
# -> 8848         return op.apply().__finalize__(self, method="apply")
#    8849
#    8850     def applymap(
#
# c:\Users\A\anaconda3\lib\site-packages\pandas\core\apply.py in apply(self)
#     731             return self.apply_raw()
#     732
# --> 733         return self.apply_standard()
#     734
#     735     def agg(self):
#
# c:\Users\A\anaconda3\lib\site-packages\pandas\core\apply.py in apply_standard(self)
#     855
#     856     def apply_standard(self):
# --> 857         results, res_index = self.apply_series_generator()
#     858
# ...

# %%
df['WorkExp'].nlargest(10)
# Out:
# ResponseId
# 4679     50.0
# 5472     50.0
# 9453     50.0
# 13265    50.0
# 14817    50.0
# 16275    50.0
# 16451    50.0
# 21489    50.0
# 22642    50.0
# 22752    50.0
# Name: WorkExp, dtype: float64

# %%
df.nlargest(10,'WorkExp')
# Out:
#                                                    MainBranch  \
# ResponseId
# 4679                           I am a developer by profession
# 5472        I am not primarily a developer, but I write co...
# 9453                           I am a developer by profession
# 13265                          I am a developer by profession
# 14817                          I am a developer by profession
# 16275                          I am a developer by profession
# 16451                          I am a developer by profession
# 21489                          I am a developer by profession
# 22642                          I am a developer by profession
# 22752       I am not primarily a developer, but I write co...
#
#                                                    Employment  \
# ResponseId
# 4679                                      Employed, full-time
# 5472        Independent contractor, freelancer, or self-em...
# 9453                                      Employed, full-time
# ...

# %%
df.describe()
# Out:
#           CompTotal  VCHostingPersonal use  VCHostingProfessional use  \
# count  3.842200e+04                    0.0                        0.0
# mean   2.342434e+52                    NaN                        NaN
# std    4.591478e+54                    NaN                        NaN
# min    0.000000e+00                    NaN                        NaN
# 25%    3.000000e+04                    NaN                        NaN
# 50%    7.750000e+04                    NaN                        NaN
# 75%    1.540000e+05                    NaN                        NaN
# max    9.000000e+56                    NaN                        NaN
#
#             WorkExp  ConvertedCompYearly
# count  36769.000000         3.807100e+04
# mean      10.242378         1.707613e+05
# std        8.706850         7.814132e+05
# min        0.000000         1.000000e+00
# 25%        4.000000         3.583200e+04
# 50%        8.000000         6.784500e+04
# 75%       15.000000         1.200000e+05
# ...

# %%
df['ConvertedCompYearly']
# Out:
# ResponseId
# 1             NaN
# 2             NaN
# 3         40205.0
# 4        215232.0
# 5             NaN
#            ...
# 73264         NaN
# 73265         NaN
# 73266         NaN
# 73267         NaN
# 73268         NaN
# Name: ConvertedCompYearly, Length: 73268, dtype: float64

# %%
df.columns
# Out:
# Index(['MainBranch', 'Employment', 'RemoteWork', 'CodingActivities', 'EdLevel',
#        'LearnCode', 'LearnCodeOnline', 'LearnCodeCoursesCert', 'YearsCode',
#        'YearsCodePro', 'DevType', 'OrgSize', 'PurchaseInfluence', 'BuyNewTool',
#        'Country', 'Currency', 'CompTotal', 'CompFreq',
#        'LanguageHaveWorkedWith', 'LanguageWantToWorkWith',
#        'DatabaseHaveWorkedWith', 'DatabaseWantToWorkWith',
#        'PlatformHaveWorkedWith', 'PlatformWantToWorkWith',
#        'WebframeHaveWorkedWith', 'WebframeWantToWorkWith',
#        'MiscTechHaveWorkedWith', 'MiscTechWantToWorkWith',
#        'ToolsTechHaveWorkedWith', 'ToolsTechWantToWorkWith',
#        'NEWCollabToolsHaveWorkedWith', 'NEWCollabToolsWantToWorkWith',
#        'OpSysProfessional use', 'OpSysPersonal use', 'VersionControlSystem',
#        'VCInteraction', 'VCHostingPersonal use', 'VCHostingProfessional use',
#        'OfficeStackAsyncHaveWorkedWith', 'OfficeStackAsyncWantToWorkWith',
# ...

# %%
df['Country']
# Out:
# ResponseId
# 1                                                      NaN
# 2                                                   Canada
# 3        United Kingdom of Great Britain and Northern I...
# 4                                                   Israel
# 5                                 United States of America
#                                ...
# 73264                                              Nigeria
# 73265                             United States of America
# 73266                             United States of America
# 73267    United Kingdom of Great Britain and Northern I...
# 73268                                               Canada
# Name: Country, Length: 73268, dtype: object

# %%
df['Country'].value_counts()
# Out:
# United States of America                                13543
# India                                                    6639
# Germany                                                  5395
# United Kingdom of Great Britain and Northern Ireland     4190
# Canada                                                   2490
#                                                         ...
# Monaco                                                      1
# Djibouti                                                    1
# Seychelles                                                  1
# Solomon Islands                                             1
# Saint Kitts and Nevis                                       1
# Name: Country, Length: 180, dtype: int64

# %%
df['Country'].value_counts(normalize=True)
# Out:
# United States of America                                0.188697
# India                                                   0.092503
# Germany                                                 0.075170
# United Kingdom of Great Britain and Northern Ireland    0.058380
# Canada                                                  0.034694
#                                                           ...
# Monaco                                                  0.000014
# Djibouti                                                0.000014
# Seychelles                                              0.000014
# Solomon Islands                                         0.000014
# Saint Kitts and Nevis                                   0.000014
# Name: Country, Length: 180, dtype: float64

# %%
y= df['Country']=='India'
df.loc[y]['MainBranch'].value_counts()
# Out:
# I am a developer by profession                                                   4625
# I am learning to code                                                            1161
# I code primarily as a hobby                                                       440
# I am not primarily a developer, but I write code sometimes as part of my work     335
# I used to be a developer by profession, but no longer am                           78
# Name: MainBranch, dtype: int64

# %%
x=df.groupby('Country')
x['MainBranch'].value_counts().head(20)
# Out:
# Country      MainBranch
# Afghanistan  I am a developer by profession                                                   43
#              I code primarily as a hobby                                                      11
#              I am learning to code                                                             7
#              I am not primarily a developer, but I write code sometimes as part of my work     6
#              I used to be a developer by profession, but no longer am                          2
# Albania      I am a developer by profession                                                   43
#              I am learning to code                                                            12
#              I am not primarily a developer, but I write code sometimes as part of my work     2
#              I code primarily as a hobby                                                       2
# ...

# %%
x=df.groupby('Country')
x['MainBranch'].value_counts(normalize=True).head(20)
# Out:
# Country      MainBranch
# Afghanistan  I am a developer by profession                                                   0.623188
#              I code primarily as a hobby                                                      0.159420
#              I am learning to code                                                            0.101449
#              I am not primarily a developer, but I write code sometimes as part of my work    0.086957
#              I used to be a developer by profession, but no longer am                         0.028986
# Albania      I am a developer by profession                                                   0.728814
#              I am learning to code                                                            0.203390
#              I am not primarily a developer, but I write code sometimes as part of my work    0.033898
#              I code primarily as a hobby                                                      0.033898
# ...

# %%
x['ConvertedCompYearly'].median().loc['India']
# Out:
# 18576.0

# %%
x['ConvertedCompYearly'].agg(['mean','median'])
# Out:
#                                               mean   median
# Country
# Afghanistan                           33914.666667  10894.0
# Albania                               24895.148148  15360.0
# Algeria                               12732.888889   7440.0
# Andorra                               98003.125000  76784.0
# Angola                                 6222.750000   3073.5
# ...                                            ...      ...
# Venezuela, Bolivarian Republic of...  17079.400000  12000.0
# Viet Nam                              37707.563830  11388.0
# Yemen                                 17464.666667  15000.0
# Zambia                                 8452.000000   6612.0
# Zimbabwe                              87596.000000  11400.0
#
# [180 rows x 2 columns]

# %%
y= df['Country']=='India'
df.loc[y]['MainBranch'].str.contains('I am learning to code').sum()
# Out:
# 1161

# %%
x['MainBranch'].apply(lambda x: x.str.contains('I am learning to code').sum())
# Out:
# Country
# Afghanistan                              7
# Albania                                 12
# Algeria                                  4
# Andorra                                  1
# Angola                                   0
#                                         ..
# Venezuela, Bolivarian Republic of...    14
# Viet Nam                                63
# Yemen                                    1
# Zambia                                   6
# Zimbabwe                                 6
# Name: MainBranch, Length: 180, dtype: int64

# %%
a = df['Country'].value_counts()
a
# Out:
# United States of America                                13543
# India                                                    6639
# Germany                                                  5395
# United Kingdom of Great Britain and Northern Ireland     4190
# Canada                                                   2490
#                                                         ...
# Monaco                                                      1
# Djibouti                                                    1
# Seychelles                                                  1
# Solomon Islands                                             1
# Saint Kitts and Nevis                                       1
# Name: Country, Length: 180, dtype: int64

# %%
b = x['MainBranch'].apply(lambda x: x.str.contains('I am learning to code').sum())
b
# Out:
# Country
# Afghanistan                              7
# Albania                                 12
# Algeria                                  4
# Andorra                                  1
# Angola                                   0
#                                         ..
# Venezuela, Bolivarian Republic of...    14
# Viet Nam                                63
# Yemen                                    1
# Zambia                                   6
# Zimbabwe                                 6
# Name: MainBranch, Length: 180, dtype: int64

# %%
c = pd.concat([a,b],axis='columns')
c
# Out:
#                                                     Country  MainBranch
# United States of America                              13543         673
# India                                                  6639        1161
# Germany                                                5395         259
# United Kingdom of Great Britain and Northern Ir...     4190         188
# Canada                                                 2490         152
# ...                                                     ...         ...
# Monaco                                                    1           0
# Djibouti                                                  1           0
# Seychelles                                                1           0
# Solomon Islands                                           1           0
# Saint Kitts and Nevis                                     1           0
#
# [180 rows x 2 columns]

# %%
c['Percentage'] = (c['MainBranch']/c['Country'])*100
c
# Out:
#                                                     Country  MainBranch  \
# United States of America                              13543         673
# India                                                  6639        1161
# Germany                                                5395         259
# United Kingdom of Great Britain and Northern Ir...     4190         188
# Canada                                                 2490         152
# ...                                                     ...         ...
# Monaco                                                    1           0
# Djibouti                                                  1           0
# Seychelles                                                1           0
# Solomon Islands                                           1           0
# Saint Kitts and Nevis                                     1           0
#
#                                                     Percentage
# ...

# %%
c.sort_values(by='Percentage',ascending=False).head(50)
# Out:
#                              Country  MainBranch  Percentage
# Papua New Guinea                   2           2  100.000000
# Cape Verde                         4           2   50.000000
# Antigua and Barbuda                2           1   50.000000
# Mauritania                         2           1   50.000000
# Gabon                              2           1   50.000000
# ...                              ...         ...         ...
# Sri Lanka                        296          53   17.905405
# South Korea                      229          41   17.903930
# China                            632         113   17.879747
# United Republic of Tanzania       28           5   17.857143
# India                           6639        1161   17.487573
#
# [50 rows x 3 columns]

# %%
c.loc['Japan']
# Out:
# Country       333.000000
# MainBranch     17.000000
# Percentage      5.105105
# Name: Japan, dtype: float64

# %%
#Check every possible value in a column
df["WorkExp"].unique()
# Out:
# array([nan,  6., 14.,  5., 15.,  4., 23.,  9., 22., 21.,  3., 28.,  7.,
#        12.,  8.,  2., 20., 27.,  1., 10., 19., 13., 30., 11., 18., 47.,
#        17., 46., 25., 24., 31.,  0., 41., 43., 40., 16., 42., 35., 32.,
#        34., 26., 36., 38., 29., 33., 44., 37., 50., 45., 39., 48., 49.])

# %%
df["WorkExp"].astype(float)
# Out:
# ResponseId
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
# 5         NaN
#          ...
# 73264     5.0
# 73265     6.0
# 73266    42.0
# 73267     NaN
# 73268     NaN
# Name: WorkExp, Length: 73268, dtype: float64

# %%
filt = (df["Country"] == "India")
India_df=df.loc[filt]

# %%
India_df.to_csv("Newdata.csv")

# %%
India_df
# Out:
#                                                    MainBranch  \
# ResponseId
# 7                                 I code primarily as a hobby
# 8                              I am a developer by profession
# 66                             I am a developer by profession
# 141                            I am a developer by profession
# 152                            I am a developer by profession
# ...                                                       ...
# 73185                          I am a developer by profession
# 73194       I used to be a developer by profession, but no...
# 73256                          I am a developer by profession
# 73258                                   I am learning to code
# 73259                          I am a developer by profession
#
#                                     Employment  \
# ResponseId
# 7                           Student, part-time
# 8           Not employed, but looking for work
# 66                         Employed, full-time
# ...

# %%
India_df.to_excel("excel.xlsx")

# %%
India_df.to_json("json.json")

# %%
from sqlalchemy import create_engine 
import psycopg2

# %%
engine = create_engine('postgresql://lion:tiger@localhost:5432/Pandas')

# %%
India_df.to_sql('ssqlll',engine)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# c:\Users\A\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    3279         try:
# -> 3280             return fn()
#    3281         except dialect.dbapi.Error as e:
#
# c:\Users\A\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in connect(self)
#     309         """
# --> 310         return _ConnectionFairy._checkout(self)
#     311
#
# c:\Users\A\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in _checkout(cls, pool, threadconns, fairy)
#     867         if not fairy:
# --> 868             fairy = _ConnectionRecord.checkout(pool)
#     869
#
# c:\Users\A\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in checkout(cls, pool)
#     475     def checkout(cls, pool):
# --> 476         rec = pool._do_get()
#     477         try:
#
# ...
